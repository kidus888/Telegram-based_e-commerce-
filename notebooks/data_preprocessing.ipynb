# %%
import pandas as pd
import re

# Load your DataFrame
df = pd.read_csv('../telegram_data.csv')

# %%
df
# Out:
#     Channel Title    Channel Username   ID  \
# 0            መነሻዬ  @meneshayeofficial  848
# 1            መነሻዬ  @meneshayeofficial  847
# 2            መነሻዬ  @meneshayeofficial  846
# 3            መነሻዬ  @meneshayeofficial  845
# 4            መነሻዬ  @meneshayeofficial  844
# ..            ...                 ...  ...
# 762          መነሻዬ  @meneshayeofficial    5
# 763          መነሻዬ  @meneshayeofficial    4
# 764          መነሻዬ  @meneshayeofficial    3
# 765          መነሻዬ  @meneshayeofficial    2
# 766          መነሻዬ  @meneshayeofficial    1
#
#                                                Message  \
# 0                                                  NaN
# 1    ተገጣጣሚዎቹን የእንጨት ብሎኮች ከመነሻዬ ሲሸምቱ ልጆችዎ ያለጥርጥር እየተ...
# 2    ስለ ህዋ ሳይንስ የሚያስተምሩ ትምህርታዊ መጫዎቻዎችን በተለያዩ አማራጮች ...
# 3    የካሪስማ ደስታ በመነሻዬ!!\n\nመነሻዬ ለልጆች የሚሆኑ ትምህርታዊ መጫዎ...
# 4    አና በ swing car ደስታዋ እጥፍ ድርብ ሆኗል!!\n👉 ያለምንም ኤሌክ...
# ..                                                 ...
# 762                                                NaN
# 763  🎯መነሻዬ\n👉ዋጋ 2600 ብር \nከድንጋይ በተሰራ ወረቀት የተመረተው በቀ...
# 764                                                NaN
# 765                                                NaN
# 766                                                NaN
#
#                           Date                         Media Path
# 0    2024-09-10 13:09:31+00:00  photos/@meneshayeofficial_848.jpg
# 1    2024-09-03 09:44:53+00:00                                NaN
# 2    2024-08-29 11:28:56+00:00                                NaN
# 3    2024-08-23 03:50:23+00:00                                NaN
# 4    2024-08-21 07:34:19+00:00                                NaN
# ..                         ...                                ...
# 762  2022-10-27 17:22:46+00:00    photos/@meneshayeofficial_5.jpg
# 763  2022-10-27 17:22:46+00:00    photos/@meneshayeofficial_4.jpg
# 764  2022-10-27 17:16:52+00:00                                NaN
# 765  2022-09-22 13:41:51+00:00                                NaN
# 766  2022-09-07 16:24:39+00:00                                NaN
#
# [767 rows x 6 columns]

# %%
print("Checking for NaN values in the 'Message' column:")
nan_count = df['Message'].isnull().sum()
print(f"Number of NaN values in 'Message' column: {nan_count}")
# Out:
# Checking for NaN values in the 'Message' column:
# Number of NaN values in 'Message' column: 39

# %%
df = df.dropna(subset=['Message'])

# Print the shape of the dataset after dropping NaN values in the "Message" column
print(f"Dataset shape after dropping NaN values in 'Message' column: {df.shape}")
# Out:
# Dataset shape after dropping NaN values in 'Message' column: (728, 6)

# %%
df.head()
# Out:
#   Channel Title    Channel Username   ID  \
# 1          መነሻዬ  @meneshayeofficial  847
# 2          መነሻዬ  @meneshayeofficial  846
# 3          መነሻዬ  @meneshayeofficial  845
# 4          መነሻዬ  @meneshayeofficial  844
# 5          መነሻዬ  @meneshayeofficial  843
#
#                                              Message  \
# 1  ተገጣጣሚዎቹን የእንጨት ብሎኮች ከመነሻዬ ሲሸምቱ ልጆችዎ ያለጥርጥር እየተ...
# 2  ስለ ህዋ ሳይንስ የሚያስተምሩ ትምህርታዊ መጫዎቻዎችን በተለያዩ አማራጮች ...
# 3  የካሪስማ ደስታ በመነሻዬ!!\n\nመነሻዬ ለልጆች የሚሆኑ ትምህርታዊ መጫዎ...
# 4  አና በ swing car ደስታዋ እጥፍ ድርብ ሆኗል!!\n👉 ያለምንም ኤሌክ...
# 5  ውድ ደንበኞቻችን ከዚህ በታች ያስቀመጥንልዎ ለልጆችዎ የሚሆኑ ትምህርታዊ ...
#
#                         Date Media Path
# 1  2024-09-03 09:44:53+00:00        NaN
# 2  2024-08-29 11:28:56+00:00        NaN
# 3  2024-08-23 03:50:23+00:00        NaN
# 4  2024-08-21 07:34:19+00:00        NaN
# 5  2024-08-20 07:08:19+00:00        NaN

# %%
message_df=df['Message']
message_df
# Out:
# 1      ተገጣጣሚዎቹን የእንጨት ብሎኮች ከመነሻዬ ሲሸምቱ ልጆችዎ ያለጥርጥር እየተ...
# 2      ስለ ህዋ ሳይንስ የሚያስተምሩ ትምህርታዊ መጫዎቻዎችን በተለያዩ አማራጮች ...
# 3      የካሪስማ ደስታ በመነሻዬ!!\n\nመነሻዬ ለልጆች የሚሆኑ ትምህርታዊ መጫዎ...
# 4      አና በ swing car ደስታዋ እጥፍ ድርብ ሆኗል!!\n👉 ያለምንም ኤሌክ...
# 5      ውድ ደንበኞቻችን ከዚህ በታች ያስቀመጥንልዎ ለልጆችዎ የሚሆኑ ትምህርታዊ ...
#                              ...
# 750    ስለ ልጆዎ ግድ ስለሚለን የምናገለግሎ በእውቀት ነው።\n     ለዛም ደስ...
# 751                  መነሻዬ ትምህርታዊ መጫወቻዎችን የሚያገኙበት ምርጥ ስፍራ
# 753                                      መነሻዬ በክብር ተከፈተ!
# 759    🎯መነሻዬ\n👉ዋጋ 2600 ብር\n📞 0989 93 93 93 📞0911 25 9...
# 763    🎯መነሻዬ\n👉ዋጋ 2600 ብር \nከድንጋይ በተሰራ ወረቀት የተመረተው በቀ...
# Name: Message, Length: 728, dtype: object

# %%
# Define a function to remove emojis
def remove_emojis(text):
    emoji_pattern = re.compile(
        "[" 
        "\U0001F600-\U0001F64F"  # emoticons
        "\U0001F300-\U0001F5FF"  # symbols & pictographs
        "\U0001F680-\U0001F6FF"  # transport & map symbols
        "\U0001F700-\U0001F77F"  # alchemical symbols
        "\U0001F780-\U0001F7FF"  # Geometric Shapes Extended
        "\U0001F800-\U0001F8FF"  # Supplemental Arrows-C
        "\U0001F900-\U0001F9FF"  # Supplemental Symbols and Pictographs
        "\U0001FA00-\U0001FA6F"  # Chess Symbols
        "\U0001FA70-\U0001FAFF"  # Symbols and Pictographs Extended-A
        "\U00002702-\U000027B0"  # Dingbats
        "\U000024C2-\U0001F251" 
        "]+", 
        flags=re.UNICODE
    )
    return emoji_pattern.sub(r'', text)

# Apply the function to the 'Message' column
df['Message'] = df['Message'].apply(remove_emojis)

# Display the updated DataFrame
print(df.head())
# Out:
#   Channel Title    Channel Username   ID  \
# 1          መነሻዬ  @meneshayeofficial  847
# 2          መነሻዬ  @meneshayeofficial  846
# 3          መነሻዬ  @meneshayeofficial  845
# 4          መነሻዬ  @meneshayeofficial  844
# 5          መነሻዬ  @meneshayeofficial  843
#
#                                              Message  \
# 1  ተገጣጣሚዎቹን የእንጨት ብሎኮች ከመነሻዬ ሲሸምቱ ልጆችዎ ያለጥርጥር እየተ...
# 2  ስለ ህዋ ሳይንስ የሚያስተምሩ ትምህርታዊ መጫዎቻዎችን በተለያዩ አማራጮች ...
# 3  የካሪስማ ደስታ በመነሻዬ!!\n\nመነሻዬ ለልጆች የሚሆኑ ትምህርታዊ መጫዎ...
# 4  አና በ swing car ደስታዋ እጥፍ ድርብ ሆኗል!!\n ያለምንም ኤሌክት...
# 5  ውድ ደንበኞቻችን ከዚህ በታች ያስቀመጥንልዎ ለልጆችዎ የሚሆኑ ትምህርታዊ ...
#
#                         Date Media Path
# 1  2024-09-03 09:44:53+00:00        NaN
# 2  2024-08-29 11:28:56+00:00        NaN
# 3  2024-08-23 03:50:23+00:00        NaN
# 4  2024-08-21 07:34:19+00:00        NaN
# 5  2024-08-20 07:08:19+00:00        NaN
# /tmp/ipykernel_30675/2866899226.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Message'] = df['Message'].apply(remove_emojis)

# %%
df.to_csv('clean_data.csv')
df
